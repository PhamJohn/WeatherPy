# %%
# Import dependencies
import pandas as pd
import numpy as np

# Import the random module.
import random

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bfe7b3eb2161fa350bcf6389c5066a81

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=500)
longs = np.random.uniform(-90.000, 90.000, size=500)
# lats_longs = zip(lats, longs)
# lats_longs

# %%
# Combining latitudes and longitudes as coordinates (2D array) to a list
lats_longs = list(zip(lats,longs))
lats_longs[0:5]

# Add the latitudes and longitudes to a list.
# coordinates = list(lats_longs)
# coordinates[0:5]
# Out:
# [(-74.64404278803798, -32.47737972700419),
#  (35.3890750365064, -68.54141730601191),
#  (69.99064078533428, -24.00743536657083),
#  (62.02369429133074, 89.3601484265032),
#  (-73.35441333726516, -22.112102841780768)]

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in lats_longs:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ushuaia ar
# hamilton bm
# illoqqortoormiut gl
# teya ru
# ushuaia ar
# puerto varas cl
# ushuaia ar
# matara lk
# illoqqortoormiut gl
# podporozhye ru
# lafia ng
# padrauna in
# punta arenas cl
# illoqqortoormiut gl
# nicoya cr
# tumannyy ru
# souillac mu
# san cristobal ec
# mahebourg mu
# hermanus za
# qaanaaq gl
# beloha mg
# kruisfontein za
# margate za
# cockburn town bs
# bolshoy tsaryn ru
# nurota uz
# lebu cl
# tasiilaq gl
# cacador br
# taolanaro mg
# marawi sd
# irtyshskiy ru
# sao filipe cv
# dikson ru
# dobrinje ba
# natal br
# ushuaia ar
# ponta do sol cv
# narsaq gl
# georgetown sh
# ponta do sol cv
# port elizabeth za
# illoqqortoormiut gl
# kintampo gh
# busselton au
# illoqqortoormiut gl
# itarema br
# cape town za
# amderma ru
# castro cl
# tasiilaq gl
# ushuaia ar
# huarmey pe
# doka sd
# ponta do sol cv
# mahebourg mu
# nola it
# calatayud es
# tibati cm
# clyde river ca
# do gonbadan ir
# lima pe
# souillac mu
# kutum sd
# tumannyy ru
# port alfred za
# izhmorskiy ru
# iqaluit ca
# belushya guba ru
# punta arenas cl
# cape town za
# ballina ie
# hithadhoo mv
# erbaa tr
# arraial do cabo br
# verkhniy baskunchak ru
# jamestown sh
# upernavik gl
# peniche pt
# east london za
# port elizabeth za
# ribeira grande pt
# hermanus za
# port alfred za
# hobyo so
# henties bay na
# elizabeth city us
# coruripe br
# los llanos de aridane es
# lebu cl
# ushuaia ar
# longyearbyen sj
# port alfred za
# sambava mg
# cidreira br
# saint-augustin ca
# ilulissat gl
# sao miguel do oeste br
# port alfred za
# mangrol in
# veraval in
# luba gq
# vestmanna fo
# cabedelo br
# nadym ru
# lannion fr
# kasane bw
# lagoa pt
# punta arenas cl
# sakti in
# longyearbyen sj
# gazojak tm
# taolanaro mg
# neuquen ar
# pangody ru
# qaanaaq gl
# taolanaro mg
# saldanha za
# mocambique mz
# dawlatabad af
# hermanus za
# salym ru
# taolanaro mg
# chiguiri arriba pa
# klaksvik fo
# dikson ru
# laguna br
# ushuaia ar
# punta arenas cl
# touros br
# ilulissat gl
# khokhlovo ru
# east london za
# walvis bay na
# longyearbyen sj
# chernukha ru
# saint-philippe re
# quatre cocos mu
# busselton au
# souillac mu
# ghanzi bw
# rylsk ru
# taolanaro mg
# castro cl
# cape town za
# hofn is
# hermanus za
# bilma ne
# jamestown sh
# longyearbyen sj
# cape town za
# surami ge
# vardo no
# illoqqortoormiut gl
# ushuaia ar
# bowmore gb
# dikson ru
# quelimane mz
# adrar dz
# buqayq sa
# lagoa pt
# bilma ne
# xuddur so
# milyutinskaya ru
# sao felix do xingu br
# iqaluit ca
# berlevag no
# tafresh ir
# east london za
# longyearbyen sj
# rawson ar
# luanda ao
# meulaboh id
# ushuaia ar
# gijon es
# barranca pe
# karkaralinsk kz
# taolanaro mg
# dikson ru
# souillac mu
# myre no
# quatre cocos mu
# qarayeri az
# abu kamal sy
# tutoia br
# soyo ao
# vagur fo
# tiznit ma
# pangoa pe
# iquique cl
# otjiwarongo na
# ushuaia ar
# attawapiskat ca
# jalu ly
# victoria sc
# ushuaia ar
# port alfred za
# canosa di puglia it
# dikson ru
# malwan in
# ushuaia ar
# mar del plata ar
# luanda ao
# bargal so
# ushuaia ar
# bredasdorp za
# mehamn no
# mahebourg mu
# ribeira grande pt
# kashi cn
# ushuaia ar
# barbar sd
# bredasdorp za
# shalya ru
# ordynskoye ru
# clyde river ca
# umzimvubu za
# geraldton au
# sarh td
# sinnamary gf
# harer et
# grindavik is
# ostrovnoy ru
# pont-a-mousson fr
# belmonte br
# reading us
# bredasdorp za
# cape town za
# beloha mg
# mutare zw
# bredasdorp za
# punta arenas cl
# hermanus za
# qaanaaq gl
# illoqqortoormiut gl
# killybegs ie
# cape town za
# leshukonskoye ru
# ushuaia ar
# busselton au
# mulchen cl
# illoqqortoormiut gl
# chuy uy
# patan in
# port alfred za
# lelydorp sr
# bredasdorp za
# sao mateus do sul br
# aswan eg
# sumbe ao
# jamestown sh
# saldanha za
# berlevag no
# riberalta bo
# saint-philippe re
# ushuaia ar
# arzakan am
# busselton au
# shelburne ca
# hazorasp uz
# georgetown sh
# belushya guba ru
# ushuaia ar
# vardo no
# ushuaia ar
# torbay ca
# hermanus za
# el paso co
# hithadhoo mv
# georgetown sh
# saint-denis re
# nanortalik gl
# jamestown sh
# ushuaia ar
# qaanaaq gl
# santa maria cv
# oistins bb
# piacabucu br
# sorland no
# touros br
# sao jose da coroa grande br
# ostrovnoy ru
# velikie luki ru
# warqla dz
# jacqueville ci
# ushuaia ar
# illoqqortoormiut gl
# caravelas br
# illoqqortoormiut gl
# floro no
# kinkala cg
# hermanus za
# kyabe td
# qaanaaq gl
# hermanus za
# barranca pe
# codrington ag
# cabildo cl
# bathsheba bb
# ushuaia ar
# sinnamary gf
# grand river south east mu
# hermanus za
# ribeira grande pt
# iqaluit ca
# richards bay za
# havre-saint-pierre ca
# arraial do cabo br
# taolanaro mg
# someshwar in
# keffi ng
# ushuaia ar
# taolanaro mg
# port alfred za
# ihosy mg
# wajir ke
# east london za
# ilulissat gl
# klaksvik fo
# upernavik gl
# gummidipundi in
# georgetown sh
# ondo ng
# ribeira grande pt
# iquique cl
# hermanus za
# carnarvon au
# hofn is
# kuressaare ee
# ushuaia ar
# huarmey pe
# hamilton bm
# longyearbyen sj
# tahta eg
# taolanaro mg
# livingstone zm
# barentsburg sj
# chapada dos guimaraes br
# amapa br
# vangaindrano mg
# paamiut gl
# kuytun cn
# henties bay na
# purpe ru
# port alfred za
# port alfred za
# tombouctou ml
# ushuaia ar
# port elizabeth za
# busselton au
# fuerte olimpo py
# gazojak tm
# rio hato pa
# hermanus za
# arauca co
# bredasdorp za
# amparafaravola mg
# hithadhoo mv
# luderitz na
# luderitz na
# chemax mx
# klaksvik fo
# ostrovnoy ru
# tasiilaq gl
# qaanaaq gl
# chuy uy
# georgetown sh
# saint-francois gp
# kruisfontein za
# walvis bay na
# sao jose da coroa grande br
# east london za
# grindavik is
# zemio cf
# cape town za
# dzhusaly kz
# ushuaia ar
# hermanus za
# ushuaia ar
# overyata ru
# cape town za
# ushuaia ar
# maloy no
# prieska za
# souillac mu
# bambous virieux mu
# bubaque gw
# jaru br
# kavaratti in
# tasiilaq gl
# grand river south east mu
# ushuaia ar
# victoria sc
# ushuaia ar
# lodwar ke
# taolanaro mg
# saint-joseph re
# ushuaia ar
# sundsvall se
# grand river south east mu
# san cristobal ec
# yokadouma cm
# port elizabeth za
# bredasdorp za
# mpulungu zm
# illoqqortoormiut gl
# belushya guba ru
# leua ao
# ouadda cf
# hamilton bm
# trofors no
# qaanaaq gl
# dikson ru
# cape town za
# grand-lahou ci
# qaanaaq gl
# pedernales do
# richards bay za
# lebu cl
# talcahuano cl
# hermanus za
# aleksandrov gay ru
# ushuaia ar
# belushya guba ru
# bredasdorp za
# barentsburg sj
# hithadhoo mv
# punta arenas cl
# ushuaia ar
# busselton au
# saint-philippe re
# joshimath in
# hithadhoo mv
# sal rei cv
# laguna br
# illoqqortoormiut gl
# ponta do sol cv
# chimore bo
# arraial do cabo br
# illoqqortoormiut gl
# paamiut gl
# victoria sc
# bathsheba bb
# batavia us
# cockburn town tc
# coihaique cl
# attawapiskat ca
# illoqqortoormiut gl
# ushuaia ar
# iqaluit ca
# georgetown sh
# georgetown sh
# ushuaia ar
# getulio vargas br
# skibbereen ie
# jamestown sh
# taolanaro mg
# kuruman za
# taolanaro mg
# piryion gr
# vila do maio cv
# port alfred za
# ouahigouya bf
# barentsburg sj
# torbay ca
# illoqqortoormiut gl
# jamestown sh
# qaanaaq gl
# casa nova br
# belushya guba ru
# richmond za
# tulle fr
# mahebourg mu
# ushuaia ar
# chuy uy
# gamba ga
# chuy uy
# illoqqortoormiut gl
# jamestown sh
# bambous virieux mu
# grand gaube mu
# oktyabrskoye ru
# finsterwalde de
# coquimbo cl
# sinnamary gf
# santa maria cv
# torbay ca
# ribeira grande pt
# kruisfontein za
# jamestown sh
# praia cv
# belushya guba ru
# saint-philippe re
# taolanaro mg
# ushuaia ar
# dolores ar
# illoqqortoormiut gl
# hambantota lk
# rocha uy

# %%
# Create an empty variable to contain cities by latitude and longitudes
cities = []

# Get city for each coordinates (latitude and longitude array)
for coordinate in lats_longs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add city that is unique into variable "cities"
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 262

# %% [markdown]
# ## Get the City Weather Data

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | hamilton
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | teya
# Processing Record 5 of Set 1 | puerto varas
# Processing Record 6 of Set 1 | matara
# Processing Record 7 of Set 1 | podporozhye
# Processing Record 8 of Set 1 | lafia
# Processing Record 9 of Set 1 | padrauna
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | nicoya
# Processing Record 12 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | san cristobal
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | beloha
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | margate
# Processing Record 21 of Set 1 | cockburn town
# Processing Record 22 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 23 of Set 1 | nurota
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | cacador
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | marawi
# Processing Record 29 of Set 1 | irtyshskiy
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | dobrinje
# Processing Record 33 of Set 1 | natal
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | kintampo
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | itarema
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | huarmey
# Processing Record 45 of Set 1 | doka
# Processing Record 46 of Set 1 | nola
# Processing Record 47 of Set 1 | calatayud
# Processing Record 48 of Set 1 | tibati
# Processing Record 49 of Set 1 | clyde river
# Processing Record 50 of Set 1 | do gonbadan
# Processing Record 1 of Set 2 | lima
# Processing Record 2 of Set 2 | kutum
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | izhmorskiy
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | ballina
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | erbaa
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | verkhniy baskunchak
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | peniche
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | hobyo
# Processing Record 18 of Set 2 | henties bay
# Processing Record 19 of Set 2 | elizabeth city
# Processing Record 20 of Set 2 | coruripe
# Processing Record 21 of Set 2 | los llanos de aridane
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | sambava
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | saint-augustin
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 28 of Set 2 | mangrol
# Processing Record 29 of Set 2 | veraval
# Processing Record 30 of Set 2 | luba
# Processing Record 31 of Set 2 | vestmanna
# Processing Record 32 of Set 2 | cabedelo
# Processing Record 33 of Set 2 | nadym
# Processing Record 34 of Set 2 | lannion
# Processing Record 35 of Set 2 | kasane
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | sakti
# Processing Record 38 of Set 2 | gazojak
# Processing Record 39 of Set 2 | neuquen
# Processing Record 40 of Set 2 | pangody
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 2 | dawlatabad
# Processing Record 44 of Set 2 | salym
# Processing Record 45 of Set 2 | chiguiri arriba
# City not found. Skipping...
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | khokhlovo
# Processing Record 50 of Set 2 | walvis bay
# Processing Record 1 of Set 3 | chernukha
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | quatre cocos
# Processing Record 4 of Set 3 | ghanzi
# Processing Record 5 of Set 3 | rylsk
# Processing Record 6 of Set 3 | hofn
# Processing Record 7 of Set 3 | bilma
# Processing Record 8 of Set 3 | surami
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | bowmore
# Processing Record 11 of Set 3 | quelimane
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 3 | xuddur
# Processing Record 15 of Set 3 | milyutinskaya
# Processing Record 16 of Set 3 | sao felix do xingu
# Processing Record 17 of Set 3 | berlevag
# Processing Record 18 of Set 3 | tafresh
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | luanda
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | gijon
# Processing Record 23 of Set 3 | barranca
# Processing Record 24 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 3 | myre
# Processing Record 26 of Set 3 | qarayeri
# Processing Record 27 of Set 3 | abu kamal
# Processing Record 28 of Set 3 | tutoia
# Processing Record 29 of Set 3 | soyo
# Processing Record 30 of Set 3 | vagur
# Processing Record 31 of Set 3 | tiznit
# Processing Record 32 of Set 3 | pangoa
# Processing Record 33 of Set 3 | iquique
# Processing Record 34 of Set 3 | otjiwarongo
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | jalu
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | canosa di puglia
# Processing Record 39 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | mehamn
# Processing Record 44 of Set 3 | kashi
# Processing Record 45 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 3 | shalya
# Processing Record 47 of Set 3 | ordynskoye
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | geraldton
# Processing Record 50 of Set 3 | sarh
# Processing Record 1 of Set 4 | sinnamary
# Processing Record 2 of Set 4 | harer
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | pont-a-mousson
# Processing Record 6 of Set 4 | belmonte
# Processing Record 7 of Set 4 | reading
# Processing Record 8 of Set 4 | mutare
# Processing Record 9 of Set 4 | killybegs
# Processing Record 10 of Set 4 | leshukonskoye
# Processing Record 11 of Set 4 | mulchen
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | patan
# Processing Record 14 of Set 4 | lelydorp
# Processing Record 15 of Set 4 | sao mateus do sul
# Processing Record 16 of Set 4 | aswan
# Processing Record 17 of Set 4 | sumbe
# Processing Record 18 of Set 4 | riberalta
# Processing Record 19 of Set 4 | arzakan
# Processing Record 20 of Set 4 | shelburne
# Processing Record 21 of Set 4 | hazorasp
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | el paso
# Processing Record 24 of Set 4 | saint-denis
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | santa maria
# Processing Record 27 of Set 4 | oistins
# Processing Record 28 of Set 4 | piacabucu
# Processing Record 29 of Set 4 | sorland
# Processing Record 30 of Set 4 | sao jose da coroa grande
# Processing Record 31 of Set 4 | velikie luki
# City not found. Skipping...
# Processing Record 32 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 4 | jacqueville
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | floro
# Processing Record 36 of Set 4 | kinkala
# Processing Record 37 of Set 4 | kyabe
# Processing Record 38 of Set 4 | codrington
# Processing Record 39 of Set 4 | cabildo
# Processing Record 40 of Set 4 | bathsheba
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | richards bay
# Processing Record 43 of Set 4 | havre-saint-pierre
# Processing Record 44 of Set 4 | someshwar
# Processing Record 45 of Set 4 | keffi
# Processing Record 46 of Set 4 | ihosy
# Processing Record 47 of Set 4 | wajir
# Processing Record 48 of Set 4 | gummidipundi
# Processing Record 49 of Set 4 | ondo
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | kuressaare
# Processing Record 2 of Set 5 | tahta
# Processing Record 3 of Set 5 | livingstone
# Processing Record 4 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 5 | chapada dos guimaraes
# Processing Record 6 of Set 5 | amapa
# Processing Record 7 of Set 5 | vangaindrano
# Processing Record 8 of Set 5 | paamiut
# Processing Record 9 of Set 5 | kuytun
# Processing Record 10 of Set 5 | purpe
# Processing Record 11 of Set 5 | tombouctou
# Processing Record 12 of Set 5 | fuerte olimpo
# Processing Record 13 of Set 5 | rio hato
# Processing Record 14 of Set 5 | arauca
# Processing Record 15 of Set 5 | amparafaravola
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | chemax
# Processing Record 18 of Set 5 | saint-francois
# Processing Record 19 of Set 5 | zemio
# Processing Record 20 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 5 | overyata
# Processing Record 22 of Set 5 | maloy
# Processing Record 23 of Set 5 | prieska
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | bubaque
# Processing Record 26 of Set 5 | jaru
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | lodwar
# Processing Record 29 of Set 5 | saint-joseph
# Processing Record 30 of Set 5 | sundsvall
# Processing Record 31 of Set 5 | yokadouma
# Processing Record 32 of Set 5 | mpulungu
# Processing Record 33 of Set 5 | leua
# Processing Record 34 of Set 5 | ouadda
# Processing Record 35 of Set 5 | trofors
# Processing Record 36 of Set 5 | grand-lahou
# Processing Record 37 of Set 5 | pedernales
# Processing Record 38 of Set 5 | talcahuano
# Processing Record 39 of Set 5 | aleksandrov gay
# Processing Record 40 of Set 5 | joshimath
# Processing Record 41 of Set 5 | sal rei
# Processing Record 42 of Set 5 | chimore
# Processing Record 43 of Set 5 | batavia
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | getulio vargas
# Processing Record 46 of Set 5 | skibbereen
# Processing Record 47 of Set 5 | kuruman
# Processing Record 48 of Set 5 | piryion
# City not found. Skipping...
# Processing Record 49 of Set 5 | vila do maio
# Processing Record 50 of Set 5 | ouahigouya
# Processing Record 1 of Set 6 | casa nova
# Processing Record 2 of Set 6 | richmond
# Processing Record 3 of Set 6 | tulle
# Processing Record 4 of Set 6 | gamba
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | oktyabrskoye
# Processing Record 7 of Set 6 | finsterwalde
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | praia
# Processing Record 10 of Set 6 | dolores
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | rocha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000 -68.3000     46.06        49          20
# 1      Hamilton      US  39.1834 -84.5333     81.41        81          28
# 2          Teya      RU  60.3778  92.6267     57.99        77         100
# 3  Puerto Varas      CL -41.3195 -72.9854     53.82        66           0
# 4        Matara      LK   5.9485  80.5353     78.46        86         100
# 5   Podporozhye      RU  60.9112  34.1706     58.01        95          24
# 6         Lafia      NG   8.4833   8.5167     72.39        96         100
# 7      Padrauna      IN  26.9025  83.9819     78.67        92         100
# 8  Punta Arenas      CL -53.1500 -70.9167     46.51        66          40
# 9        Nicoya      CR  10.1483 -85.4520     89.15        77          98
#
#    Wind Speed   Current Description
# 0       17.27            few clouds
# 1        1.01            light rain
# 2        2.04       overcast clouds
# 3        6.91             clear sky
# 4        9.69       overcast clouds
# 5        5.61            few clouds
# 6        4.36       overcast clouds
# 7        2.01  heavy intensity rain
# 8       11.50      scattered clouds
# 9        6.78       overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the weather_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
